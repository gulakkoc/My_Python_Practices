# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1><p style="text-align: center;">Data Analysis with Python <br>Project - 1</p><h1> - Traffic Police Stops, Part - 4 (Solution Session) <img src="https://docs.google.com/uc?id=17CPCwi3_VvzcS87TOsh4_U8eExOhL6Ki" class="img-fluid" alt="CLRSWY" width="200" height="100">

# %% [markdown]
# In this chapter, you will use a **second dataset** to explore the impact of **weather conditions** on police behavior during traffic stops. You will practice **merging** and **reshaping** datasets, assessing whether a data source is trustworthy, working with **categorical** data, and other advanced skills.

# %% [markdown]
# ## Plotting the temperature

# %% [markdown]
# In this exercise, you'll examine the ``temperature`` columns from the ``weather`` dataset to assess whether the data seems trustworthy. First you'll print the summary statistics, and then you'll visualize the data using a **box plot**.
#
# When deciding whether the values seem reasonable, keep in mind that the temperature is measured in degrees **Fahrenheit**, not Celsius!

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Read ``weather.csv`` into a ``DataFrame`` named ``weather``.
# *   Select the temperature columns (``TMIN``, ``TAVG``, ``TMAX``) and print their ``summary statistics`` using the ``.describe()`` method.
# *   Create a **box plot** to visualize the temperature columns.
# *   Display the plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns',None)

# %%
weather = pd.read_csv("weather.csv")

# %%
weather.head()
# Out:
#        STATION        DATE  AWND  TAVG  TMAX  TMIN  WT01  WT02  WT03  WT04  \
# 0  USC00379423  2005-01-01   NaN   NaN  47.0  28.0   NaN   NaN   NaN   NaN
# 1  USC00379423  2005-01-02   NaN   NaN  52.0  24.0   NaN   NaN   NaN   NaN
# 2  USC00379423  2005-01-03   NaN   NaN  48.0  27.0   NaN   NaN   NaN   NaN
# 3  USC00379423  2005-01-04   NaN   NaN  54.0  40.0   NaN   NaN   NaN   NaN
# 4  USC00379423  2005-01-05   NaN   NaN  44.0  31.0   NaN   NaN   NaN   NaN
#
#    WT05  WT06  WT07  WT08  WT09  WT10  WT11  WT13  WT14  WT15  WT16  WT17  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WT18  WT19  WT21  WT22
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN

# %%
weather.shape
# Out:
# (8022, 26)

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8022 entries, 0 to 8021
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  8022 non-null   object
#  1   DATE     8022 non-null   object
#  2   AWND     4017 non-null   float64
#  3   TAVG     1217 non-null   float64
#  4   TMAX     8005 non-null   float64
#  5   TMIN     7996 non-null   float64
#  6   WT01     1777 non-null   float64
#  7   WT02     221 non-null    float64
#  8   WT03     227 non-null    float64
#  9   WT04     119 non-null    float64
#  10  WT05     360 non-null    float64
#  11  WT06     25 non-null     float64
#  12  WT07     79 non-null     float64
#  13  WT08     404 non-null    float64
#  14  WT09     69 non-null     float64
#  15  WT10     2 non-null      float64
#  16  WT11     3 non-null      float64
#  17  WT13     1175 non-null   float64
#  18  WT14     575 non-null    float64
#  19  WT15     6 non-null      float64
#  20  WT16     1326 non-null   float64
#  21  WT17     12 non-null     float64
#  22  WT18     345 non-null    float64
#  23  WT19     4 non-null      float64
#  24  WT21     18 non-null     float64
#  25  WT22     32 non-null     float64
# dtypes: float64(24), object(2)
# memory usage: 1.6+ MB

# %%
weather[["TMIN", "TAVG", "TMAX"]].describe()
# Out:
#               TMIN         TAVG         TMAX
# count  7996.000000  1217.000000  8005.000000
# mean     42.099425    52.493016    61.247096
# std      17.386667    17.829792    18.495043
# min     -10.000000     6.000000    13.000000
# 25%      29.000000    39.000000    46.000000
# 50%      42.000000    54.000000    62.000000
# 75%      57.000000    68.000000    77.000000
# max      77.000000    86.000000   102.000000

# %%
weather[["TMIN", "TAVG", "TMAX"]].plot(kind = "box")

plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Plotting the temperature difference

# %% [markdown]
# In this exercise, you'll continue to assess ``whether`` the dataset seems trustworthy by plotting the difference between the maximum and minimum temperatures.
#
# What do you notice about the resulting **histogram**? Does it match your expectations, or do you see anything unusual?

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Create a new column in the ``weather`` ``DataFrame`` named ``TDIFF`` that represents the difference between the maximum and minimum temperatures.
# *   Print the summary statistics for ``TDIFF`` using the ``.describe()`` method.
# *   Create a histogram with ``20 bins`` to visualize ``TDIFF``.
# *   Display the plot.

# %%
weather["TDIFF"] = weather["TMAX"] - weather["TMIN"]

# %%
weather["TDIFF"]
# Out:
# 0       19.0
# 1       28.0
# 2       21.0
# 3       14.0
# 4       13.0
#         ...
# 8017    17.0
# 8018    14.0
# 8019    12.0
# 8020     8.0
# 8021    15.0
# Name: TDIFF, Length: 8022, dtype: float64

# %%
weather["TDIFF"].describe()
# Out:
# count    7994.000000
# mean       19.149237
# std         7.009716
# min       -25.000000
# 25%        14.000000
# 50%        19.000000
# 75%        24.000000
# max        48.000000
# Name: TDIFF, dtype: float64

# %%
weather.TDIFF.plot(kind = "hist", bins = 20)

plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Counting bad weather conditions

# %% [markdown]
# The ``weather`` ``DataFrame`` contains ``20`` columns that start with ``'WT'``, each of which represents a bad weather condition. For example:
#
# *   ``WT05`` indicates ``"Hail"``
# *   ``WT11`` indicates ``"High or damaging winds"``
# *   ``WT17`` indicates ``"Freezing rain"``
#
# For every row in the dataset, each ``WT`` column contains either a ``1`` (meaning the condition was present that day) or ``NaN`` (meaning the condition was not present).
#
# In this exercise, you'll quantify ``"how bad"`` the weather was each day by counting the number of ``1`` values in each row.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Copy the columns ``WT01`` through ``WT22`` from ``weather`` to a new ``DataFrame`` named ``WT``.
# *   Calculate the sum of each row in ``WT``, and store the results in a new weather column named ``bad_conditions``.
# *   Replace any ``missing values`` in ``bad_conditions`` with a ``0``. (This has been done for you.)
# *   Create a **histogram** to visualize ``bad_conditions``, and then display the plot.

# %%
weather.head()
# Out:
#        STATION        DATE  AWND  TAVG  TMAX  TMIN  WT01  WT02  WT03  WT04  \
# 0  USC00379423  2005-01-01   NaN   NaN  47.0  28.0   NaN   NaN   NaN   NaN
# 1  USC00379423  2005-01-02   NaN   NaN  52.0  24.0   NaN   NaN   NaN   NaN
# 2  USC00379423  2005-01-03   NaN   NaN  48.0  27.0   NaN   NaN   NaN   NaN
# 3  USC00379423  2005-01-04   NaN   NaN  54.0  40.0   NaN   NaN   NaN   NaN
# 4  USC00379423  2005-01-05   NaN   NaN  44.0  31.0   NaN   NaN   NaN   NaN
#
#    WT05  WT06  WT07  WT08  WT09  WT10  WT11  WT13  WT14  WT15  WT16  WT17  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WT18  WT19  WT21  WT22  TDIFF
# 0   NaN   NaN   NaN   NaN   19.0
# 1   NaN   NaN   NaN   NaN   28.0
# 2   NaN   NaN   NaN   NaN   21.0
# 3   NaN   NaN   NaN   NaN   14.0
# 4   NaN   NaN   NaN   NaN   13.0

# %%
WT = weather.loc[:, "WT01" : "WT22"]

# %%
WT.head()
# Out:
#    WT01  WT02  WT03  WT04  WT05  WT06  WT07  WT08  WT09  WT10  WT11  WT13  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WT14  WT15  WT16  WT17  WT18  WT19  WT21  WT22
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
weather["bad_conditions"] = WT.sum(axis = "columns")
#weather["bad_conditions"] = WT.sum(axis = 1)

# %%
weather.bad_conditions.value_counts(dropna = False)
# Out:
# 0.0    5738
# 1.0     628
# 4.0     476
# 3.0     380
# 2.0     368
# 5.0     282
# 6.0     101
# 7.0      41
# 8.0       4
# 9.0       4
# Name: bad_conditions, dtype: int64

# %%
weather["bad_conditions"] = weather.bad_conditions.fillna(0).astype("int")

# %%
weather.sample(7)
# Out:
#           STATION        DATE   AWND  TAVG  TMAX  TMIN  WT01  WT02  WT03  \
# 1918  USC00379423  2010-04-17    NaN   NaN  47.0  38.0   NaN   NaN   NaN
# 6865  USW00014765  2012-10-31   6.26   NaN  55.0  48.0   1.0   1.0   NaN
# 403   USC00379423  2006-02-11    NaN   NaN  30.0  18.0   NaN   NaN   NaN
# 5006  USW00014765  2007-09-29  10.29   NaN  76.0  54.0   NaN   NaN   NaN
# 2735  USC00379423  2012-07-18    NaN   NaN  94.0  75.0   NaN   NaN   NaN
# 7981  USW00014765  2015-11-21   7.61  45.0  52.0  36.0   NaN   NaN   NaN
# 6571  USW00014765  2012-01-11   5.82   NaN  42.0  28.0   NaN   NaN   NaN
#
#       WT04  WT05  WT06  WT07  WT08  WT09  WT10  WT11  WT13  WT14  WT15  WT16  \
# 1918   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6865   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   1.0   NaN   NaN   1.0
# 403    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5006   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2735   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7981   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6571   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#       WT17  WT18  WT19  WT21  WT22  TDIFF  bad_conditions
# 1918   NaN   NaN   NaN   NaN   NaN    9.0               0
# 6865   NaN   NaN   NaN   NaN   NaN    7.0               4
# 403    NaN   NaN   NaN   NaN   NaN   12.0               0
# 5006   NaN   NaN   NaN   NaN   NaN   22.0               0
# 2735   NaN   NaN   NaN   NaN   NaN   19.0               0
# 7981   NaN   NaN   NaN   NaN   NaN   16.0               0
# 6571   NaN   NaN   NaN   NaN   NaN   14.0               0

# %%
weather.bad_conditions.plot(kind = "hist" )

plt.show()

# %%
weather.bad_conditions.value_counts(dropna = False)
# Out:
# 0    5738
# 1     628
# 4     476
# 3     380
# 2     368
# 5     282
# 6     101
# 7      41
# 9       4
# 8       4
# Name: bad_conditions, dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# ## Rating the weather conditions

# %% [markdown]
# In the previous exercise, you counted the number of bad weather conditions each day. In this exercise, you'll use the counts to create a *rating system** for the weather.
#
# The counts range from ``0`` to ``9``, and should be converted to ratings as follows:
#
# *   Convert ``0`` to ``'good'``
# *   Convert ``1`` through ``4`` to ``'bad'``
# *   Convert ``5`` through ``9`` to ``'worse'``

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Count the **unique** values in the ``bad_conditions`` column and sort the ``index``.
# *   Create a ``dictionary`` called ``mapping`` that maps the ``bad_conditions`` integers to strings as specified above.
# *   Convert the ``bad_conditions`` integers to strings using the ``mapping`` and store the results in a new column called ``rating``.
# *   Count the **unique** values in ``rating`` to verify that the integers were properly converted to strings.

# %%
weather.bad_conditions.value_counts(dropna = False).sort_index()
# Out:
# 0    5738
# 1     628
# 2     368
# 3     380
# 4     476
# 5     282
# 6     101
# 7      41
# 8       4
# 9       4
# Name: bad_conditions, dtype: int64

# %%
mapping = {0:'good', 1:'bad', 2:'bad', 3:'bad', 4:'bad', 5:'worse', 6:'worse', 7:'worse', 8:'worse', 9:'worse'}
#weather['rating']=weather.bad_conditions.replace({0:'good', 1:'bad', 2:'bad', 3:'bad', 4:'bad', 5:'worse', 6:'worse', 7:'worse', 8:'worse', 9:'worse'})

# %%
weather["rating"] = weather.bad_conditions.map(mapping)

# %%
weather.rating.value_counts(dropna = False)
# Out:
# good     5738
# bad      1852
# worse     432
# Name: rating, dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# ## Changing the data type to category

# %% [markdown]
# Since the ``rating`` column only has a few possible values, you'll change its data type to ``category`` in order to store the data more efficiently. You'll also specify a logical order for the categories, which will be useful for future exercises.

# %% [markdown]
# **INSTRUCTIONS**
#
# *   Create a ``list`` object called ``cats`` that lists the weather ratings in a logical order: ``'good'``, ``'bad'``, ``'worse'``.
# *   Change the data type of the ``rating`` column from ``object`` to ``category``. Make sure to use the ``cats list`` to define the category ordering.
# *   Examine the ``head`` of the ``rating`` column to confirm that the categories are logically ordered.

# %% [markdown]
# At the end of the day why do we care about using categorical values? There are 3 main reasons:
#
# 1.We can define a custom sort order which can improve summarizing and reporting the data. In the example above, “X-Small” < “Small” < “Medium” < “Large” < “X-Large”. Alphabetical sorting would not be able to reproduce that order.
#
# 2.Some of the python visualization libraries can interpret the categorical data type to apply approrpiate statistical models or plot types.
#
# 3.Categorical data uses less memory which can lead to performance improvements.

# %%
weather.rating[0]
# Out:
# 'good'

# %%
type(weather.rating[0])
# Out:
# str

# %%
cats = ["good", "bad", "worse"]

# %%
weather["rating"] = pd.Categorical(weather["rating"], ordered = True, categories = cats)

# %%
weather.rating.head()
# Out:
# 0    good
# 1    good
# 2    good
# 3    good
# 4    good
# Name: rating, dtype: category
# Categories (3, object): ['good' < 'bad' < 'worse']

# %%
weather.rating.tail()
# Out:
# 8017     bad
# 8018    good
# 8019     bad
# 8020     bad
# 8021     bad
# Name: rating, dtype: category
# Categories (3, object): ['good' < 'bad' < 'worse']

# %%
weather.rating.min()
# Out:
# 'good'

# %%
weather.rating.max()
# Out:
# 'worse'

# %%
weather.rating.sort_values()
# Out:
# 0        good
# 3832     good
# 3831     good
# 3830     good
# 3829     good
#         ...
# 4853    worse
# 4852    worse
# 4851    worse
# 4871    worse
# 4010    worse
# Name: rating, Length: 8022, dtype: category
# Categories (3, object): ['good' < 'bad' < 'worse']

# %% [markdown]
# ***

# %% [markdown]
# ## Preparing the DataFrames

# %% [markdown]
# In this exercise, you'll prepare the **traffic stop** and **weather rating** ``DataFrames`` so that they're ready to be merged:
#
# With the ``ri`` ``DataFrame``, you'll move the ``stop_datetime`` index to a ``column`` since the index will be lost during the merge.
#
# With the ``weather`` ``DataFrame``, you'll select the ``DATE`` and ``rating`` columns and put them in a new ``DataFrame``.

# %% [markdown]
# **INSTRUCTIONS**
#
# * Reset the ``index`` of the ``ri`` ``DataFrame``.
#
# * Examine the ``head`` of ``ri`` to verify that ``stop_datetime`` is now a ``DataFrame`` column,
# and the ``index`` is now the default ``integer`` index.
#
# * Create a new ``DataFrame`` named ``weather_rating`` that contains only the ``DATE`` and ``rating`` columns from the ``weather`` ``DataFrame``.
#
# * Examine the ``head`` of ``weather_rating`` to verify that it contains the proper columns.

# %% [markdown]
# > Before starting your work from this part of this chapter **repeat the steps which you did in the first chapter for preparing the ``ri`` data.** Continue to this chapter based on where you were in the end of the first chapter.

# %%
import pandas as pd

ri = pd.read_csv('police.csv')

drop_columns=["state", "county_name", "county_fips", "fine_grained_location"]
ri.drop(drop_columns, axis='columns', inplace=True)

ri.dropna(subset=['driver_gender'], inplace=True)

ri['is_arrested'] = ri.is_arrested.astype('bool')

combined = ri.stop_date.str.cat(ri.stop_time, sep=' ')
ri['stop_datetime'] = pd.to_datetime(combined)
# Out:
# C:\Users\igdem\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ***

# %%
#ri.reset_index(inplace=True)

# %%
ri.head()
# Out:
#               id   stop_date stop_time location_raw police_department  \
# 0  RI-2005-00001  2005-01-02     01:55      Zone K1               600
# 1  RI-2005-00002  2005-01-02     20:30      Zone X4               500
# 3  RI-2005-00004  2005-01-04     12:55      Zone X4               500
# 4  RI-2005-00005  2005-01-06     01:30      Zone X4               500
# 5  RI-2005-00006  2005-01-12     08:05      Zone X1                 0
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw driver_race  \
# 0             M          1985.0        20.0               W       White
# 1             M          1987.0        18.0               W       White
# 3             M          1986.0        19.0               W       White
# 4             M          1978.0        27.0               B       Black
# 5             M          1973.0        32.0               B       Black
#
#                     violation_raw  violation search_conducted search_type_raw  \
# 0                        Speeding   Speeding            False             NaN
# 1                        Speeding   Speeding            False             NaN
# 3  Equipment/Inspection Violation  Equipment            False             NaN
# 4  Equipment/Inspection Violation  Equipment            False             NaN
# 5                Call for Service      Other            False             NaN
#
#   search_type  contraband_found stop_outcome  is_arrested stop_duration  \
# 0         NaN             False     Citation        False      0-15 Min
# 1         NaN             False     Citation        False     16-30 Min
# 3         NaN             False     Citation        False      0-15 Min
# 4         NaN             False     Citation        False      0-15 Min
# 5         NaN             False     Citation        False       30+ Min
#
#   out_of_state  drugs_related_stop district       stop_datetime
# 0        False               False  Zone K1 2005-01-02 01:55:00
# 1        False               False  Zone X4 2005-01-02 20:30:00
# 3        False               False  Zone X4 2005-01-04 12:55:00
# 4        False               False  Zone X4 2005-01-06 01:30:00
# 5         True               False  Zone X1 2005-01-12 08:05:00

# %% [markdown]
# ## Merging the DataFrames

# %% [markdown]
# Merging the DataFrames
# In this exercise, you'll ``merge`` the ``ri`` and ``weather_rating`` ``DataFrames`` into a new ``DataFrame``, ``ri_weather``.
#
# The ``DataFrames`` will be joined using the ``stop_date`` column from ``ri`` and the ``DATE`` column from ``weather_rating``. Thankfully the date formatting matches exactly, which is not always the case!
#
# Once the merge is complete, you'll set ``stop_datetime`` as the index, which is the column you saved in the previous exercise.

# %% [markdown]
# Examine the shape of the ``ri`` ``DataFrame``.
# ``Merge`` the ``ri`` and ``weather_rating`` ``DataFrames`` using a ``left join``.
# Examine the ``shape`` of ``ri_weather`` to confirm that it has two more columns but the same number of rows as ``ri``.
# Replace the ``index`` of ``ri_weather`` with the ``stop_datetime`` column.

# %%
weather_rating = weather[["DATE", "rating"]]

# %%
weather_rating.head()
# Out:
#          DATE rating
# 0  2005-01-01   good
# 1  2005-01-02   good
# 2  2005-01-03   good
# 3  2005-01-04   good
# 4  2005-01-05   good

# %%
weather_rating.shape
# Out:
# (8022, 2)

# %%
weather_rating.DATE.nunique()
# Out:
# 4017

# %%
ri.stop_date[3]
# Out:
# '2005-01-04'

# %%
weather_rating.DATE[3]
# Out:
# '2005-01-04'

# %%
ri.shape
# Out:
# (480584, 23)

# %%
weather_rating.drop_duplicates(subset='DATE', keep='last', inplace=True)
# Out:
# <ipython-input-45-f3b8bfb5f9dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather_rating.drop_duplicates(subset='DATE', keep='last', inplace=True)

# %%
ri_weather = pd.merge(left = ri, right = weather_rating, left_on = "stop_date", right_on = "DATE", how = "left")

# %%
ri_weather.shape
# Out:
# (480584, 25)

# %%
ri_weather
# Out:
#                                 id   stop_date stop_time location_raw  \
# stop_datetime
# 2005-01-02 01:55:00  RI-2005-00001  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30:00  RI-2005-00002  2005-01-02     20:30      Zone X4
# 2005-01-04 12:55:00  RI-2005-00004  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30:00  RI-2005-00005  2005-01-06     01:30      Zone X4
# 2005-01-12 08:05:00  RI-2005-00006  2005-01-12     08:05      Zone X1
# ...                            ...         ...       ...          ...
# 2015-12-31 22:46:00  RI-2015-47061  2015-12-31     22:46      Zone X1
# 2015-12-31 22:47:00  RI-2015-47062  2015-12-31     22:47      Zone X4
# 2015-12-31 23:08:00  RI-2015-47063  2015-12-31     23:08      Zone X3
# 2015-12-31 23:44:00  RI-2015-47064  2015-12-31     23:44      Zone K2
# 2015-12-31 23:48:00  RI-2015-47065  2015-12-31     23:48      Zone K3
#
#                     police_department driver_gender  driver_age_raw  \
# stop_datetime
# 2005-01-02 01:55:00               600             M          1985.0
# 2005-01-02 20:30:00               500             M          1987.0
# 2005-01-04 12:55:00               500             M          1986.0
# 2005-01-06 01:30:00               500             M          1978.0
# 2005-01-12 08:05:00                 0             M          1973.0
# ...                               ...           ...             ...
# 2015-12-31 22:46:00                 0             M          1959.0
# 2015-12-31 22:47:00               500             M          1988.0
# 2015-12-31 23:08:00               200             M          1980.0
# 2015-12-31 23:44:00               900             M          1984.0
# 2015-12-31 23:48:00               300             M          1988.0
#
#                      driver_age driver_race_raw driver_race  \
# stop_datetime
# 2005-01-02 01:55:00        20.0               W       White
# 2005-01-02 20:30:00        18.0               W       White
# 2005-01-04 12:55:00        19.0               W       White
# 2005-01-06 01:30:00        27.0               B       Black
# 2005-01-12 08:05:00        32.0               B       Black
# ...                         ...             ...         ...
# 2015-12-31 22:46:00        56.0               H    Hispanic
# 2015-12-31 22:47:00        27.0               W       White
# 2015-12-31 23:08:00        35.0               H    Hispanic
# 2015-12-31 23:44:00        31.0               W       White
# 2015-12-31 23:48:00        27.0               H    Hispanic
#
#                                       violation_raw            violation  \
# stop_datetime
# 2005-01-02 01:55:00                        Speeding             Speeding
# 2005-01-02 20:30:00                        Speeding             Speeding
# 2005-01-04 12:55:00  Equipment/Inspection Violation            Equipment
# 2005-01-06 01:30:00  Equipment/Inspection Violation            Equipment
# 2005-01-12 08:05:00                Call for Service                Other
# ...                                             ...                  ...
# 2015-12-31 22:46:00                        Speeding             Speeding
# 2015-12-31 22:47:00          Registration Violation  Registration/plates
# 2015-12-31 23:08:00  Equipment/Inspection Violation            Equipment
# 2015-12-31 23:44:00                        Speeding             Speeding
# 2015-12-31 23:48:00              Seatbelt Violation            Seat belt
#
#                     search_conducted search_type_raw search_type  \
# stop_datetime
# 2005-01-02 01:55:00            False             NaN         NaN
# 2005-01-02 20:30:00            False             NaN         NaN
# 2005-01-04 12:55:00            False             NaN         NaN
# 2005-01-06 01:30:00            False             NaN         NaN
# 2005-01-12 08:05:00            False             NaN         NaN
# ...                              ...             ...         ...
# 2015-12-31 22:46:00            False             NaN         NaN
# 2015-12-31 22:47:00            False             NaN         NaN
# 2015-12-31 23:08:00            False             NaN         NaN
# 2015-12-31 23:44:00            False             NaN         NaN
# 2015-12-31 23:48:00            False             NaN         NaN
#
#                      contraband_found stop_outcome  is_arrested stop_duration  \
# stop_datetime
# 2005-01-02 01:55:00             False     Citation        False      0-15 Min
# 2005-01-02 20:30:00             False     Citation        False     16-30 Min
# 2005-01-04 12:55:00             False     Citation        False      0-15 Min
# 2005-01-06 01:30:00             False     Citation        False      0-15 Min
# 2005-01-12 08:05:00             False     Citation        False       30+ Min
# ...                               ...          ...          ...           ...
# 2015-12-31 22:46:00             False     Citation        False      0-15 Min
# 2015-12-31 22:47:00             False     Citation        False      0-15 Min
# 2015-12-31 23:08:00             False     Citation        False      0-15 Min
# 2015-12-31 23:44:00             False     Citation        False      0-15 Min
# 2015-12-31 23:48:00             False     Citation        False      0-15 Min
#
#                     out_of_state  drugs_related_stop district        DATE  \
# stop_datetime
# 2005-01-02 01:55:00        False               False  Zone K1  2005-01-02
# 2005-01-02 20:30:00        False               False  Zone X4  2005-01-02
# 2005-01-04 12:55:00        False               False  Zone X4  2005-01-04
# 2005-01-06 01:30:00        False               False  Zone X4  2005-01-06
# 2005-01-12 08:05:00         True               False  Zone X1  2005-01-12
# ...                          ...                 ...      ...         ...
# 2015-12-31 22:46:00         True               False  Zone X1  2015-12-31
# 2015-12-31 22:47:00        False               False  Zone X4  2015-12-31
# 2015-12-31 23:08:00        False               False  Zone X3  2015-12-31
# 2015-12-31 23:44:00        False               False  Zone K2  2015-12-31
# 2015-12-31 23:48:00        False               False  Zone K3  2015-12-31
#
#                     rating
# stop_datetime
# 2005-01-02 01:55:00    bad
# 2005-01-02 20:30:00    bad
# 2005-01-04 12:55:00    bad
# 2005-01-06 01:30:00  worse
# 2005-01-12 08:05:00  worse
# ...                    ...
# 2015-12-31 22:46:00    bad
# 2015-12-31 22:47:00    bad
# 2015-12-31 23:08:00    bad
# 2015-12-31 23:44:00    bad
# 2015-12-31 23:48:00    bad
#
# [480584 rows x 24 columns]

# %%
ri_weather.set_index('stop_datetime', inplace=True)

# %% [markdown]
# ***

# %% [markdown]
# ## Comparing arrest rates by weather rating

# %% [markdown]
# Do police officers arrest drivers more often when the weather is bad? Find out below!
#
# - **First**, you'll calculate the **overall arrest rate**.
#
# - **Then**, you'll calculate the **arrest rate** for each of the **weather ratings** you previously assigned.
#
# - **Finally**, you'll add **violation type** as a second factor in the analysis, to see if that accounts for any differences in the arrest rate.
#
# Since you previously defined a logical order for the weather categories, ``good < bad < worse``, they will be sorted that way in the results.

# %% [markdown]
# ***

# %%
ri_weather.is_arrested.mean()
# Out:
# 0.03454755048024903

# %%
ri_weather.groupby('rating').is_arrested.mean()
# Out:
# rating
# good     0.033004
# bad      0.035199
# worse    0.039360
# Name: is_arrested, dtype: float64

# %%
ri_weather.groupby(['rating','violation']).is_arrested.mean()
# Out:
# rating  violation
# good    Equipment              0.056484
#         Moving violation       0.055621
#         Other                  0.082492
#         Registration/plates    0.076831
#         Seat belt              0.025503
#         Speeding               0.013214
# bad     Equipment              0.059704
#         Moving violation       0.057976
#         Other                  0.084991
#         Registration/plates    0.092749
#         Seat belt              0.028845
#         Speeding               0.013368
# worse   Equipment              0.094373
#         Moving violation       0.062249
#         Other                  0.058704
#         Registration/plates    0.098673
#         Seat belt              0.000000
#         Speeding               0.016600
# Name: is_arrested, dtype: float64

# %% [markdown]
# ## Selecting From a mult-indexed Series

# %% [markdown]
# The output of a single ``.groupby()`` operation on multiple columns is a ``Series`` with a ``MultiIndex``. Working with this type of object is similar to working with a ``DataFrame``:
#
# The ``outer`` index level is like the ``DataFrame`` rows.
# The ``inner`` index level is like the ``DataFrame`` columns.
# In this exercise, you'll practice accessing data from a multi-indexed ``Series`` using the ``.loc[]`` accessor.

# %% [markdown]
# **INSTRUCTIONS**
#
# - Save the output of the ``.groupby()`` operation from the last exercise as a new object, ``arrest_rate``.
# - Print the ``arrest_rate`` ``Series`` and examine it.
# - Print the arrest rate for ``moving violations`` in bad weather.
# - Print the arrest rates for ``speeding violations`` in all three weather conditions.

# %%
arrest_rate = ri_weather.groupby(['violation', 'rating']).is_arrested.mean()

# %%
arrest_rate
# Out:
# violation            rating
# Equipment            good      0.056484
#                      bad       0.059704
#                      worse     0.094373
# Moving violation     good      0.055621
#                      bad       0.057976
#                      worse     0.062249
# Other                good      0.082492
#                      bad       0.084991
#                      worse     0.058704
# Registration/plates  good      0.076831
#                      bad       0.092749
#                      worse     0.098673
# Seat belt            good      0.025503
#                      bad       0.028845
#                      worse     0.000000
# Speeding             good      0.013214
#                      bad       0.013368
#                      worse     0.016600
# Name: is_arrested, dtype: float64

# %%
arrest_rate.loc['Moving violation','bad']
# Out:
# 0.05797625940938043

# %%
#arrest_rate.xs(key=('Moving violation','bad'))

# %% [markdown]
# ***

# %% [markdown]
# ## Reshaping the arrest rate data

# %% [markdown]
# In this exercise, you'll start by **reshaping** the ``arrest_rate`` ``Series`` into a ``DataFrame``. This is a useful step when working with any multi-indexed ``Series``, since it enables you to access the full range of ``DataFrame`` methods.
#
# Then, you'll create the exact same ``DataFrame`` using a ``pivot table``. This is a great example of how pandas often gives you more than one way to reach the same result!

# %% [markdown]
# **INSTRUCTIONS**
#
# - ``unstack`` the ``arrest_rate`` ``Series`` to ``reshape`` it into a ``DataFrame``.
# - Create the exact same ``DataFrame`` using a ``pivot table``! Each of the three ``.pivot_table()`` parameters should be specified as one of the ``ri_weather`` columns.

# %%
arrest_rate.unstack()
# Out:
# rating                   good       bad     worse
# violation
# Equipment            0.056484  0.059704  0.094373
# Moving violation     0.055621  0.057976  0.062249
# Other                0.082492  0.084991  0.058704
# Registration/plates  0.076831  0.092749  0.098673
# Seat belt            0.025503  0.028845  0.000000
# Speeding             0.013214  0.013368  0.016600

# %%
ri_weather.pivot_table(values=['is_arrested','driver_age'],index='violation',columns='rating',aggfunc='mean')
# Out:
#                     driver_age                       is_arrested            \
# rating                    good        bad      worse        good       bad
# violation
# Equipment            31.673801  31.926147  31.477937    0.056484  0.059704
# Moving violation     35.759748  35.916336  38.151580    0.055621  0.057976
# Other                39.745590  39.452805  40.733871    0.082492  0.084991
# Registration/plates  32.653494  32.755568  32.919607    0.076831  0.092749
# Seat belt            32.201584  32.323001  32.913043    0.025503  0.028845
# Speeding             33.479660  33.507257  33.401628    0.013214  0.013368
#
#
# rating                  worse
# violation
# Equipment            0.094373
# Moving violation     0.062249
# Other                0.058704
# Registration/plates  0.098673
# Seat belt            0.000000
# Speeding             0.016600

# %%
#ri_weather.reset_index().pivot(values=['driver_age'],columns='rating')
